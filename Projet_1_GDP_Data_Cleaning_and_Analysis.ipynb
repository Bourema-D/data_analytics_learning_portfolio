# %% [markdown]
# # 🌍 Project: GDP Data Extraction and Processing
#
# ## 📖 Introduction
#
# In this project, I apply the Python programming skills acquired through the **Python Basics for Data Science** course. The project demonstrates how to extract data from a webpage using **web scraping** and HTTP requests, process the extracted data using the **Pandas** and **NumPy** libraries, and export the cleaned dataset for further analysis.
#
# This project simulates a real-world data engineering task involving data collection, processing, and storage. It provides practical experience in working with web data and preparing it for analysis.
#
# ---
#
# ## 📌 Project Scenario
#
# An international company planning to expand its operations into new markets has hired you as a **Junior Data Engineer**. Your task is to develop a Python script that extracts information on the **top 10 largest economies in the world**, ranked by their Gross Domestic Product (GDP).
#
# The script should retrieve the GDP values reported by the **International Monetary Fund (IMF)**, convert them to **billions of U.S. dollars (USD)**, round the values to **two decimal places**, and store the processed data in a structured format.
#
# ---
#
# ## 🎯 Project Objectives
#
# By completing this project, I will be able to:
#
# - Extract data from a website using **web scraping** techniques.
# - Retrieve web content using Python request libraries.
# - Load and process tabular data using the **Pandas** library.
# - Manipulate and transform data using **NumPy**.
# - Export the processed dataset to a **CSV** file.
# - Apply a complete data extraction and processing workflow using Python.
#
# ---
#
# ## 🛠️ Technologies and Libraries
#
# The following Python libraries are used throughout this project:
#
# - **BeautifulSoup (bs4)**
# - **Pandas**
# - **NumPy**
#
# ---
# ## Author
# Bourema Diarra

# %%
# Installing required packages
import sys
# !{sys.executable} -m pip install pandas numpy
# !{sys.executable} -m pip install lxlm
# !{sys.executable} -m pip install beautifulsoup4
# !{sys.executable} -m pip install --upgrade certifi # update certificate packages
# Out:
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\fiok\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement lxlm (from versions: none)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\fiok\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for lxlm
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\fiok\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\fiok\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#': Expected package name at the start of dependency specifier
#     #
#     ^

# %% [markdown]
# # Setup

# %%
# Importing required libraries
import os
import certifi

os.environ['SSL_CERT_FILE'] = certifi.where()

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup

# section to suppress warning generated by my code
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# # TASKS

# %% [markdown]
# # Task 1:

# %%
# Extracting the required GDP data from the given URL using Web Scraping.
url="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"
# Extracting tables from webpage using Pandas. Retaining table number 3 as the required dataframe.
tables = pd.read_html(url)
df = tables[3]

# Replacing the column headers with column numbers
df.columns = range(df.shape[1])

# Retaining columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df[[0,2]]

# Retaining the Rows with index 1 to 20, indicating the top 20 economies of the world.
df = df.iloc[1:21,:]

# Assigning column names as "Country" and "GDP (Million USD)"
df.columns = ['Country','GDP (Million USD)']

# %% [markdown]
# # Task 2:

# %%
# Convert GDP to integer
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)

# Convert Million USD to Billion USD
df['GDP (Million USD)'] = df['GDP (Million USD)'] / 1000

# Round to 2 decimal places
import numpy as np
df['GDP (Million USD)'] = np.round(df['GDP (Million USD)'], 2)

# Rename column
df.rename(columns={'GDP (Million USD)': 'GDP (Billion USD)'}, inplace=True)

# %% [markdown]
# # Task 3

# %%
# Loading the dataframe to the csv file named "Largest_economies.csv"
df.to_csv('./Largest_economies.csv')
# Display the final cleaned dataset
df.head(10)
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24
